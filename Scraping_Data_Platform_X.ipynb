# %% [markdown]
# # **DIVA OCTAVIANI - 2311102006**

# %% [markdown]
# ### **Twitter Authentication Token**

# %%
twitter_auth_token = "a58079d301fded8089a6e24a2de6210a8dd29124"

# %% [markdown]
# ### **Install Library**

# %%
# Pandas untuk pengolahan data
# !pip install pandas

# update package list
# !sudo apt-get update

# install dependencies
# !sudo apt-get install -y ca-certificates curl gnupg

# membuat folder keyring untuk repository
# !sudo mkdir -p /etc/apt/keyrings

# download key repository Node.js
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# menambahkan repository Node.js
# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# update repository
# !sudo apt-get update

# install Node.js
# !sudo apt-get install nodejs -y

# cek versi Node.js
# !node -v
# Out:
# ...
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://deb.nodesource.com/node_24.x nodistro InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
# install playwright dependencies
# !npx playwright install-deps
# Out:
# ⠙⠹⠸⠼⠴⠦Installing dependencies...
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:7 https://deb.nodesource.com/node_24.x nodistro InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# ...

# %% [markdown]
# ### **Scraping Data Tweet**

# %%
filename = 'scraping_x_korupsi.csv'
search_keyword = 'korupsi'
limit = 1100

# jalankan tool tweet-harvest untuk scraping tweet
# !npx -y tweet-harvest@latest -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.7.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/scraping_x_korupsi.csv, renaming to ./tweets-data/scraping_x_korupsi.old.csv
#
# -- Scrolling... (1) (2) (3) (4)
# Filling in keywords: korupsi
#
#  (5)
#
# Your tweets saved to: /content/tweets-data/scraping_x_korupsi.csv
# Total tweets saved: 20
#
#
# Your tweets saved to: /content/tweets-data/scraping_x_korupsi.csv
# Total tweets saved: 40
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/scraping_x_korupsi.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# ...

# %% [markdown]
# ### **File Hasil Scraping**

# %%
import pandas as pd

# path file hasil scraping
file_path = "/content/tweets-data/scraping_x_korupsi.csv"

# membaca file CSV
df = pd.read_csv(file_path)

# menampilkan data
display(df)
# Out:
#       conversation_id_str                created_at  favorite_count  \
# 0     2031765638545568164  2026-03-12T05:10:25.000Z               0
# 1     2031960908428427710  2026-03-12T05:10:07.000Z               0
# 2     2031678225345360064  2026-03-12T05:08:33.000Z               0
# 3     2031742182940708986  2026-03-12T05:07:50.000Z               1
# 4     2031678225345360064  2026-03-12T05:06:11.000Z               0
# 5     2031853951620931953  2026-03-12T05:05:11.000Z               0
# 6     2031959338806644751  2026-03-12T05:04:06.000Z               0
# 7     2031959338806644751  2026-03-12T05:03:57.000Z               0
# 8     2030930969860124848  2026-03-12T05:03:19.000Z               0
# 9     2031959105448133044  2026-03-12T05:02:57.000Z               0
# 10    2031959044014133346  2026-03-12T05:02:42.000Z               0
# 11    2031678225345360064  2026-03-12T05:02:36.000Z               0
# 12    2031958868193153317  2026-03-12T05:02:00.000Z               0
# ...

# %% [markdown]
# ### **Kolom Terpilih**

# %%
data_x = df[[
    "username",
    "full_text",
    "created_at",
    "favorite_count",
    "retweet_count"
]]

data_x.columns = [
    "Username",
    "Isi Tweet",
    "Tanggal Tweet",
    "Jumlah Like",
    "Jumlah Retweet"
]

display(data_x)
# Out:
#              Username                                          Isi Tweet  \
# 0      ChandraMan7679  @ImamBesar212 China komunis terapkan hukuman m...
# 1       jus_alpukat97  Maling gak usah dikasih hati\n\nhttps://t.co/O...
# 2             BosWagu  @IndonesiaFedera @Pakde_ian Cek dulu peraturan...
# 3       chandratitius  @ArvinHonami Iya, baru kepikiran Danantara mel...
# 4          iyankecil0  @IndonesiaFedera dia korupsi kouta haji loh an...
# 5     micielaandressa          @enginafess makan fuit korupsi juga bang?
# 6       lehon_mangolu  Transformasi Bea Cukai adalah langkah nyata me...
# 7       lehon_mangolu  Presiden Prabowo mendorong agar digitalisasi s...
# 8        leeminhogita  @Franken_blues Ccok lah drpd PSI yg ccok gbing...
# 9       jeep_jeff_jip                   Korupsi untuk membeli gaya hidup
# 10        seketikanet  Bupati aktif kembali diciduk KPK. Diduga ada i...
# 11         ikn1890947  @IndonesiaFedera Belum ada keputusan terkait k...
# ...

# %% [markdown]
# ### **Simpan File**

# %%
data_x.to_excel("scraping_x.xlsx")
